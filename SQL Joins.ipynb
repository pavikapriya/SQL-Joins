# %% [markdown]
# ###ASSIGNMENT:SQL Joins

# %% [markdown]
# ---

# %% [markdown]
# **Question 1. Retrieve all customers who have placed at least one order.**

# %% [markdown]
# ![Screenshot 2026-01-21 181148.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 2. Retrieve all customers and their orders, including customers who have not placed any orders**

# %% [markdown]
# ![Screenshot 2026-01-21 181733.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 3. Retrieve all orders and their corresponding customers, including orders placed by unknown customers.**

# %% [markdown]
# ![Screenshot 2026-01-21 191144.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 4. Display all customers and orders, whether matched or not.**

# %% [markdown]
# ![Screenshot 2026-01-21 195137.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 5. Find customers who have not placed any orders**

# %% [markdown]
# ![Screenshot 2026-01-21 195928.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 6. Retrieve customers who made payments but did not place any orders.**

# %% [markdown]
# ![Screenshot 2026-01-21 202005.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 7. Generate a list of all possible combinations between Customers and Orders.**

# %% [markdown]
# ![Screenshot 2026-01-21 202612.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 8. Show all customers along with order and payment amounts in one table.**

# %% [markdown]
# ![Screenshot 2026-01-21 203744.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 9. Retrieve all customers who have both placed orders and made payments.**

# %% [markdown]
# ![Screenshot 2026-01-21 204939.png](data:image/png;base64,...)

# %% [markdown]
# ---
